# %%
import sys
from datetime import date
from pathlib import Path

import pandas as pd

ROOT = Path.cwd().resolve()
if (ROOT / "src" / "config").is_dir():
    PROJECT_ROOT = ROOT
elif (ROOT.parent / "src" / "config").is_dir():
    PROJECT_ROOT = ROOT.parent
else:
    raise RuntimeError("Execute na raiz do repo ou em notebooks/")

SRC = PROJECT_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 200)
pd.set_option("display.max_rows", 20)

try:
    from IPython.display import display
except ImportError:
    display = print  # type: ignore[misc, assignment]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 13
#       9     PROJECT_ROOT = ROOT
#      10 elif (ROOT.parent / "src" / "config").is_dir():
#      11     PROJECT_ROOT = ROOT.parent
#      12 else:
# ---> 13     raise RuntimeError("Execute na raiz do repo ou em notebooks/")
#      14
#      15 SRC = PROJECT_ROOT / "src"
#      16 if str(SRC) not in sys.path:
#
# RuntimeError: Execute na raiz do repo ou em notebooks/

# %%
from app.providers.anbima.client import AnbimaClient, VNA

# %%
provider = AnbimaClient()

# %%
vna = provider.fetch_for_dates(VNA, ["2025-05-26"])
vna
# Out:
# [[{'data_referencia': '2025-05-26',
#    'titulos': [{'tipo_titulo': 'NTN-B',
#      'codigo_selic': '760199',
#      'index': 0.37,
#      'tipo_correcao': 'P',
#      'data_validade': '2025-05-16',
#      'vna': 4511.9568},
#     {'tipo_titulo': 'NTN-C',
#      'codigo_selic': '770100',
#      'index': -0.22,
#      'tipo_correcao': 'P',
#      'data_validade': '2025-05-21',
#      'vna': 6586.646865},
#     {'tipo_titulo': 'LFT',
#      'codigo_selic': '210100',
#      'index': 14.65,
#      'tipo_correcao': 'O',
#      'data_validade': '2025-05-23',
#      'vna': 16616.592308}]}]]
